# %% [markdown]
# <a href="https://colab.research.google.com/github/Lokitha-S/sample/blob/main/pratice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python code for generating QR code

# %%
pip install qrcode
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 1.5 MB/s eta 0:00:00
# ...

# %%
import qrcode
from PIL import Image

# %%
data=input('Enter anything to generate QR:')
qr=qrcode.QRCode(version=3,box_size=8,border=4)
qr.add_data(data)
qr.make(fit=True)
image=qr.make_image(fill='black',back_color='aqua')
image.save('qr.png')
Image.open('qr.png')
# Out:
# Enter anything to generate QR:https://earth.google.com/
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=296x296>

# %% [markdown]
# Google Earth in python

# %%
import webbrowser

# %%
google_earth_url='https://earth.google.com/web/'
webbrowser.open(google_earth_url)
# Out:
# False

# %% [markdown]
# Arc Twirl Pattern using Python

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig,ax=plt.subplots(figsize=(3,3))
ax.set_xlim(-1.2,1.2)
ax.set_ylim(-1.2,1.2)
ax.set_aspect('equal')
ax.axis('off')
num_arcs=100
angle_step=np.pi/10
radius_step=0.01
for i in range(num_arcs):
  theta=np.linspace(0,np.pi,50)
  r=i*radius_step
  x=r*np.cos(theta)
  y=r*np.sin(theta)
  angle=i*angle_step
  x_rot=x*np.cos(angle)-y*np.sin(angle)
  y_rot=x*np.sin(angle)+y*np.cos(angle)
  ax.plot(x_rot,y_rot,color=plt.cm.viridis(i/num_arcs),lw=2)
plt.show()

# %%
 ax.plot(x_rot,y_rot,color=plt.cm.viridis(i/num_arcs),lw=2)
